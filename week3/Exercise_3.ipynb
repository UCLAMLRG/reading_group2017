# %%
import numpy as np
import pylab as pl

# %%
dat = np.loadtxt('input_ex6.dat')

label=['ID','SS-IN','SED-IN','COND-IN','SS-OUT','SED-OUT','COND-OUT','STAT']

# %%
for i in range(1,7):
    pl.hist(dat[:,i])
    pl.xlabel(label[i])
    pl.show()
